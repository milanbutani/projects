# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 3.5MB/s
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1

# %%
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
import nltk
import nltk
nltk.download('stopwords')
from sklearn.tree import DecisionTreeClassifier
from google.colab import files
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer


test = pd.read_csv('gdrive/My Drive/yelp_test.csv')
train = pd.read_csv('gdrive/My Drive/yelp_train.csv')
sample = pd.read_csv('gdrive/My Drive/yelp_sample.csv')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# #All Data

# %%
#stop words are words such as is, the, as, and, for... that are commonly used in sentences
stop_words = set(stopwords.words('english'))


analyser = SentimentIntensityAnalyzer()

# turns user_elite into a number of years
def elite(i):
    if i == 'None':
        return 0
    else:
        return i.count(',') + 1

# turns the text into list of all words in text
def punc_split(i):
  punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
  my_str = i.lower()
  no_punct = ""
  for char in my_str:
    if char not in punctuations:
      no_punct = no_punct + char
  return no_punct.split()

# calculates average word length in the tet
def avg_word_len(i):
  return np.mean([len(w) for w in punc_split(i)])

#turns string of a date and returns the int of the year
def dateyear(i):
  return pd.to_datetime(i).year

#returns list of nonstop words
def remove_stops(i):
  word_list = punc_split(i)
  nonstop = []
  for word in word_list:
    if word not in stop_words:
      nonstop.append(word)
  return nonstop

#finds average length of nonstop words
def nonstop_word_len(i):
	return np.mean([len(w) for w in remove_stops(i)])

#sentiment analyzer score
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    return score

# %%
def process5sa(df):
    d = df[['cool', 'funny', 'useful', 'text', 'user_average_stars', 
            'user_elite', 'user_yelping_since', 'business_average_stars',
            'business_categories', 'business_review_count', 'text','business_city']]
    
    #average user and business stars
    avg_stars = np.asarray(df['user_average_stars'])
    b_avg_stars = np.asarray(df['business_average_stars'])
    
    #log of cool, useful, funny votes
    log_cool = np.asarray(np.log(df['cool'] + 1))
    log_useful = np.asarray(np.log(df['useful'] + 1))
    log_funny = np.asarray(np.log(df['funny'] + 1))
    
    #applies elite to user_elite
    years_elite = np.asarray(df['user_elite'].apply(elite))
    
    #turns yelping_since into a year
    year_since = np.asarray([pd.to_datetime(i).year for i in df['user_yelping_since']])
    
    #proportion of elite years from years yelping since
    proportion_elite = years_elite/(2019 - year_since)
    
    #length of each text
    text_len = np.asarray([len(i) for i in df['text']])
    
    #turns each text into a list of words in that text
    punc_spl = np.asarray([punc_split(i) for i in df['text']])
    
    #number of words in a text
    num_words = np.asarray([len(i) for i in punc_spl])
    
    #number of unique words in a text
    num_uwords = np.asarray([len(set(i)) for i in punc_spl])
    
    #proportion of unique words in a text
    proportion_unique = num_uwords/num_words
    
    #average word length in a text
    word_len = np.asarray([np.mean([len(i) for i in j]) for j in punc_spl])
    
    #sentiment analysis
    scores = [sentiment_analyzer_scores(i) for i in df['text']]
    compound_scores = [i['compound'] for i in scores]
    pos_scores = [i['pos'] for i in scores]
    neg_scores = [i['neg'] for i in scores]
    
    
    #dictionary ot data
    data = {'User stars': avg_stars,
            'Business avg stars' : b_avg_stars,
            'Cool' : log_cool,
            'Funny' : log_funny,
            'Useful' : log_useful,
            'Years elite' : years_elite,
            'Yelping since' : year_since,
            'Proportion elite' : proportion_elite,
            'Text length' : text_len,
            'Number of words' : num_words,
            'Unique words' : num_uwords,
            'Proportion of unique words' : proportion_unique,
            'Average word length' : word_len,
            'Compound senti' : compound_scores,
            'Pos senti': pos_scores,
            'Neg senti': neg_scores
           }
    
    #returns dataframe from the data above
    return pd.DataFrame(data)

# %%
def dtc(train, test, func):
  #creates a DTC object
  dtc66 = DecisionTreeClassifier(random_state=66, max_depth=12)
  
  #train and test data processed
  pro_train = func(train)
  pro_test = func(test)
  
  #fitting the DTC
  dtc66.fit(pro_train, train['is_good_rating'])
  
  #training score
  print(dtc66.score(pro_train, train['is_good_rating']))
  
  #array of predictions
  predictions = dtc66.predict(pro_test)
  return predictions

# %%
#turn predictions into downloaded file:
def submission(array, name):
  #creates a dataframe from the prediction array 
  prediction_df = sample.copy()
  prediction_df['is_good_rating'] = array
  new = prediction_df.set_index('review_id')
  #turns dataframe into csv file
  new.to_csv(name +'.csv')
  files.download(name + '.csv')

# %%
pred_final = dtc(train, test, process5sa)

# %%
submission(pred_final, 'final')

# %%
dtc66 = DecisionTreeClassifier(random_state=66, max_depth=12)
  
  #train and test data processed
pro_train = process5sa(train)
  #pro_test = func(test)
  
  #fitting the DTC
dtc66.fit(pro_train, train['is_good_rating'])
  
  #training score
print(dtc66.score(pro_train, train['is_good_rating']))
  
  #array of predictions
trainp = dtc66.predict(pro_train)
#submission(train, 'train_pred')
# Out:
# 0.8719208333333334

# %%
def submission(array, name):
  #creates a dataframe from the prediction array 
  prediction_df = sample.copy()
  prediction_df['is_good_rating'] = array
  new = prediction_df.set_index('review_id')
  #turns dataframe into csv file
  new.to_csv(name +'.csv')
  files.download(name + '.csv')

# %%
trainp
# Out:
# array([0, 1, 1, ..., 1, 1, 0])

# %%
train['pred'] = trainp
train['pred'].to_frame().to_csv('train_pred_milan.csv')
files.download('train_pred_milan.csv')

# %%
train
# Out:
#                      review_id             business_id  ... is_good_rating pred
# 0       9uu-JXdQuQ3rXOd1Vxv8kA  8zN3nV0zbtE377_XhlvabA  ...              0    0
# 1       UbCgugoTK2MfBmtU_8PXaQ  wJ-PcjemwR44WitIJsDzsA  ...              0    1
# 2       6oF9_NR1O5Y_NOE6INXfrg  fP4sMlVw_MvyGNv4xeTGDA  ...              1    1
# 3       kyYWrcrr83GnJ7m_VEvwCA  hgWMxKhrnOUd3m5nOUBIkA  ...              0    1
# 4       K2X3XG9_M3EM0TWguo2bCw  KMKPusWbBaIORB669W0EeQ  ...              0    0
# 5       8BTtH9kpDTbU17j0qWX-Tw  JJcp5T5WQW3Z7zHPvsM9Yg  ...              1    1
# 6       KTqCUw0I4esm4BHAPjBk7Q  qjnJFZtsY_nfRzoL3J_UWQ  ...              0    0
# 7       knaVMFxnKn86p1dW2QRfQg  769NudnrUxWFtJCGU66A_A  ...              0    0
# 8       oSgFvpNrQcFZFCUlPlDL7A  czEmZSWIXuaBs0cTQNs6cQ  ...              1    1
# 9       _XUL-9rr6_GS4VXeL_jkjw  luxQ9RFLDM0ksWvlvVSUAA  ...              1    1
# 10      wvMo6Q0D5QP5_JunNta5Pg  M8S7poDhCIzqQx1--GB-ww  ...              0    0
# 11      AeJ5JQbhxnIcGnRGgWwzVQ  TryUg8Noo4EYMXE-93vVOw  ...              1    1
# 12      mbl9YqdULmRpXae9n932Yg  z_dSEPKwDL9Vtw1LrAAHWQ  ...              0    0
# 13      riC2HIFMLy_0jzLmDiTWmA  wohnV9hjNfbXJusIOseSXQ  ...              1    1
# 14      w847bm0CGp_3TBLg2m_bmw  NvKNe9DnQavC9GstglcBJQ  ...              1    1
# 15      Ba-Y5OFouvkSlnS2oxBuAQ  nA3DdgIQVROeQg98YCyeZw  ...              1    1
# 16      WFV1gqEcx1j9tXQqubGciQ  f_eiOrEcMnkHB7GvQVOHkQ  ...              1    1
# 17      bFVv2ab7rwCR_4OPKpxEXw  X0qAF43gdcd5Deah3drNuQ  ...              1    1
# 18      VvV8R9KYuPGC8VlHRrSBQA  eLFfWcdb7VkqNyTONksHiQ  ...              1    1
# 19      Xihu7oYPYvki-8EZ1VHrlg  ZXfMiPsPv-cH7GMQ-5-mhA  ...              0    0
# 20      EbVJ5tChkU2V8iOpqTedxA  LkXdSdPLY3_7rwI9PrY5qA  ...              1    1
# 21      TJ3lO_azTVJ8C9hS8sB1Xw  20jL_MFfIa2NCdrrcApLOQ  ...              0    0
# 22      0nfMM3FBzBiyq6RsQkc_aw  j69-Rap-yQkY6anmjyclZw  ...              1    0
# 23      vAHFYbMPtfap3FY-lYIIaQ  qltrxd6_usFu1Q0mM5ZCNQ  ...              1    1
# 24      E_xKuwLpiWGbSOb9_vzdRw  Vg1C_1eqwIwkZLIXGMTW3g  ...              1    1
# 25      tD97Y5MBs1vK5p2rmeOJUA  oxeW1tSB-e_oIzCQZtqyTw  ...              1    0
# 26      uZ4D205NYOgTfq3t_qm_oA  yA6dKNm_zl1ucZCnwW8ZCg  ...              0    0
# 27      ZBtOhs0ikd6_drCxZgBGlw  MAuSh7NKoT__CQ4BumoayA  ...              0    0
# 28      Q1GXRJvd75FnR9AWLl0VVg  mbPaXByWZBZUGqvh8ewmTA  ...              1    1
# 29      kj29XnbWlWFYA1tFqwfDbQ  HfuIfYB_CxMAAJiEnxDl9w  ...              1    1
# ...                        ...                     ...  ...            ...  ...
# 239970  gJMwyY26FPeZjcYTgsxJoA  CDff_u-AJabyRIWTnY-4bQ  ...              0    0
# 239971  U8G7iwAJmdx5sXcszTnZeA  Gt4z3AylNTsEPDkzkaC7HA  ...              1    1
# 239972  NBrg8kxxzs_TU_jInA4WQw  lI9kBUGqXMlFWT-Wi1pt_Q  ...              1    1
# 239973  BizMEu-hGnQW_ii_dFMU3w  JHN09M-CRTGln2rRnS9hWw  ...              0    0
# 239974  gK0XcI_u7ZRX3yS_VwGlng  Ne_RFg5uyaCUS523Un3i7g  ...              1    1
# 239975  4zHa_D-Tcic2LCwzZSchaA  f4x1YBxkLrZg652xt2KR5g  ...              0    1
# 239976  M7xC9lgu79R74C-KeCnNXQ  3uIXuw878fNjxZ2Li1diFg  ...              1    1
# 239977  HWGXgv__U_ucHZh23cuKvw  6V_7ldr9tjmet0BdAnC34A  ...              1    1
# 239978  Z473nS0iRrDGwzs7LH2M5w  3Gt3xskppi9jZuTrwrhLNg  ...              1    1
# 239979  E2RA-G_Mr_p2B_WuQjeDtw  i2rKCB-s456I0fcX_7iTqA  ...              0    0
# 239980  w_uLH7tUxL1vndib-8ZlPw  epETdeCmoF_-ufT5b8ACUA  ...              1    1
# 239981  h_xaF3wqqpUng4-04GeNXw  qSa3L7cy8Gju4ZLs50ycag  ...              0    1
# 239982  -V8m1JPSOcxr5kAI-tum_w  I_a74zmgR-X03LsKISWPcg  ...              1    1
# 239983  oqumpIYvtdxmxwJKZvY5xQ  rwMsL9BhGDG6r0J5zJEpYQ  ...              1    1
# 239984  U8_cQ_TEuzKBvTM26kS4HA  wuDNjKgBIa-12y7nF7BXcw  ...              0    0
# 239985  PpqidSuoqF_SxM24azPp8g  yHGE1n4R5ysN548RAe1-DA  ...              1    1
# 239986  L46X3SlvO88xtlusGr1hFg  ERfGoZcgrmF8p89FIs9_TA  ...              1    1
# 239987  2U_z167sIg8RhNfNz8v1WA  ALrEOM54-J_ulSfJqOfb8g  ...              1    1
# 239988  0uNrCyhYKePIYrkDmWIbGA  I0f12eU-xFn6Kd_4H57jrQ  ...              1    1
# 239989  sElliH4C4LaB6gu6izvTmA  DkYS3arLOhA8si5uUEmHOw  ...              1    1
# 239990  paPmjGbucBtwyW6OMwu5Xw  0zTLMQOZhiCp9GFtegiFsw  ...              1    1
# 239991  4Vm8Q15ZQzgzHIFpQrXGBw  NoF90rswXBHESSyDaWeKKA  ...              1    1
# 239992  BLenYtAtZ1Lomrrlr0TZBQ  9HDU4onlEZU27fUbF-m7wA  ...              1    1
# 239993  M-c0nNiScU_dawFPRg0gLQ  Ma7FGiFyKPVG7DzD8dLVVw  ...              1    1
# 239994  38lB-mH78wlyZilNUea6PQ  eavP59x5DOpGwVFhxbG4Cg  ...              1    0
# 239995  EIM3PcXzLvslWdeKznoCPQ  zb61eT_ChYctlCXcIqlW6Q  ...              1    0
# 239996  Jit4Fjf06je0bJOMjB5Vbw  f2z4RM_ungk_zQwcpZcpcQ  ...              0    1
# 239997  HCzbb_iwzohq1nXoo1bPiw  tMYYSWyTppDcF070Hmy-kQ  ...              0    1
# 239998  tREQWcuagPyADPz-pxeHaA  DkYS3arLOhA8si5uUEmHOw  ...              0    1
# 239999  vUWM1ReLBaP3TFni0dphvQ  -BGePny4xouLAtRNgikUYg  ...              0    0
#
# [240000 rows x 21 columns]

# %%
predf = train[['review_id', 'pred']]
predf.to_csv('milan.csv')
files.download('milan.csv')

# %%
sample
# Out:
#                     review_id  is_good_rating
# 0      SiQGQ__poSeG1oKHVem30g               1
# 1      rFZPxXnZZuEfO5Cj8SprGw               1
# 2      DU9CeH0kUfN8LO7V02fxaA               1
# 3      dJgLik5M3vvHYHDkIW62qA               1
# 4      fi9Pbb8Z4bzzlHaxXGEJTg               1
# 5      uTqh1QYTsbZWQzEFN9GJpw               1
# 6      _3r-ySAFPD-khtsLnnXSvg               1
# 7      23WAFia8X-oKzJ3ITadiMQ               1
# 8      A2hyFWfQCN_un9RMNidi-g               1
# 9      POw-zNBEj28okTFmScK9lg               1
# 10     9xWNjYzFUCLhYIJPAt-W_A               1
# 11     mWk15zO4ZYust8TRS15dDw               1
# 12     tQ1mXTiVlmc7Jsmb28Ez6g               1
# 13     cDV5nJ3FFK-VWjoyWGip5g               1
# 14     HVyn7RTrEePqlKF6zMoOMg               1
# 15     lvi7N8cT1Rc7Z1t8gq_p3w               1
# 16     PF0mqA6C8IscVcPvMlFHeQ               1
# 17     uMn6vjVmjrG2sYOFZ1IokA               1
# 18     Iz0ApOpP-D0QbJQOyma87A               1
# 19     4elPJekrv4V3tRnLdRrGpg               1
# 20     B2QZ-XuzNTy1WYU2X4XftA               1
# 21     lyQUthwM0qaNQa5_9Bxcfg               1
# 22     bQF44LWb8BZsGZwRimYUCA               1
# 23     Cdt8FqNUYN-yZKxaiA0OUg               1
# 24     mWegB-dcaxBVi8P9e46y-Q               1
# 25     QJYdYAUoaVIRjzhvVSBxKQ               1
# 26     jsDQimitLNdg8uy7wyhMVw               1
# 27     yBgCb55u2gK-zHGUhylEjw               1
# 28     WOMK-rg1syqEQhzhg-DMLw               1
# 29     unwcbIydDu7vAQ24RmIgLg               1
# ...                       ...             ...
# 59970  Dz8gJvVOYn6b-AhDx2SL0w               1
# 59971  Pe5FPbakBwamF8NjE-s8Cw               1
# 59972  -qMTmM9QnbnvSKxD2sp00w               1
# 59973  Ttg207s_-bZxRQxGiVhYww               1
# 59974  QXM13cJHbU201jZ6TY_T_g               1
# 59975  ZfgTiFIiWphRs-YCcwRaLA               1
# 59976  PwAEsyitaVeTshe9vBjdEg               1
# 59977  TVRKiHNcloXKCwKtCv8zWQ               1
# 59978  HTK5EG9kiWn9dOrWBQzQog               1
# 59979  ZhKjuXz8niPJBGfbZ1QYeQ               1
# 59980  OI2qm0HCeW9hgh-QCSXpZQ               1
# 59981  QBmHWMb9efLHa_Hef4VbQA               1
# 59982  vbTivRO0nisqiFEokgRtOw               1
# 59983  W71wwEqAT6CbFHjEkwdIGA               1
# 59984  xIO0VQRsqAZGZu5WRVaKyg               1
# 59985  KdXPEpcIfu4i7T48BGJ0tg               1
# 59986  AK2A-bVbAAMQ2P-aSpH0fQ               1
# 59987  SulXsRbWTcwEeKX0Ue7Dlw               1
# 59988  8NhPcZHjhQYWJHA6nr1-UA               1
# 59989  wtZ4KSBi-P5elbXAKEy5BQ               1
# 59990  COOA9kzqKTgwZ1hnUDOZFA               1
# 59991  wftUWzXQqolxhvSh5YhMwA               1
# 59992  sayE6UYFOdPamdXbDly8rA               1
# 59993  fC504VpZ2tVtpcsmw-u0Zw               1
# 59994  y0xbf09KDk10Xp-WTsRJhg               1
# 59995  S-27cgCKBOVmGjJjnt3_xg               1
# 59996  Y94Nq9WLPVv8xhCiAx-Y0w               1
# 59997  PG4BYlPaUv6bLUhknj_pJA               1
# 59998  gj4FVS9D81if2LDNwmjTxg               1
# 59999  wtkSHq1pwQMX35xWlHZzNg               1
#
# [60000 rows x 2 columns]
